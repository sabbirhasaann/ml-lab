# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
dataset = pd.read_csv('titanic/gender_submission.csv')

# %%
dataset.index
# Out:
# RangeIndex(start=0, stop=418, step=1)

# %%
dataset.columns
# Out:
# Index(['PassengerId', 'Survived'], dtype='object')

# %%
dataset.dtypes
# Out:
# PassengerId    int64
# Survived       int64
# dtype: object

# %%
dataset.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]>

# %%
dataset.values
# Out:
# array([[ 892,    0],
#        [ 893,    1],
#        [ 894,    0],
#        [ 895,    0],
#        [ 896,    1],
#        [ 897,    0],
#        [ 898,    1],
#        [ 899,    0],
#        [ 900,    1],
#        [ 901,    0],
#        [ 902,    0],
#        [ 903,    0],
#        [ 904,    1],
#        [ 905,    0],
#        [ 906,    1],
#        [ 907,    1],
#        [ 908,    0],
#        [ 909,    0],
#        [ 910,    1],
#        [ 911,    1],
#        [ 912,    0],
#        [ 913,    0],
#        [ 914,    1],
#        [ 915,    0],
#        [ 916,    1],
#        [ 917,    0],
#        [ 918,    1],
#        [ 919,    0],
#        [ 920,    0],
#        [ 921,    0],
#        [ 922,    0],
#        [ 923,    0],
#        [ 924,    1],
#        [ 925,    1],
#        [ 926,    0],
#        [ 927,    0],
#        [ 928,    1],
#        [ 929,    1],
#        [ 930,    0],
#        [ 931,    0],
#        [ 932,    0],
#        [ 933,    0],
#        [ 934,    0],
# ...

# %%
dataset.shape
# Out:
# (418, 2)

# %%
dataset.axes
# Out:
# [RangeIndex(start=0, stop=418, step=1),
#  Index(['PassengerId', 'Survived'], dtype='object')]

# %%
dataset.size
# Out:
# 836

# %%
sc = StandardScaler()
data_scaled = sc.fit_transform(dataset)
print(data_scaled)
# Out:
# [[-1.72791209 -0.75592895]
#  [-1.71962474  1.32287566]
#  [-1.71133739 -0.75592895]
#  [-1.70305005 -0.75592895]
#  [-1.6947627   1.32287566]
#  [-1.68647535 -0.75592895]
#  [-1.678188    1.32287566]
#  [-1.66990065 -0.75592895]
#  [-1.6616133   1.32287566]
#  [-1.65332596 -0.75592895]
#  [-1.64503861 -0.75592895]
#  [-1.63675126 -0.75592895]
#  [-1.62846391  1.32287566]
#  [-1.62017656 -0.75592895]
#  [-1.61188922  1.32287566]
#  [-1.60360187  1.32287566]
#  [-1.59531452 -0.75592895]
#  [-1.58702717 -0.75592895]
#  [-1.57873982  1.32287566]
#  [-1.57045248  1.32287566]
#  [-1.56216513 -0.75592895]
#  [-1.55387778 -0.75592895]
#  [-1.54559043  1.32287566]
#  [-1.53730308 -0.75592895]
#  [-1.52901573  1.32287566]
#  [-1.52072839 -0.75592895]
#  [-1.51244104  1.32287566]
#  [-1.50415369 -0.75592895]
#  [-1.49586634 -0.75592895]
#  [-1.48757899 -0.75592895]
#  [-1.47929165 -0.75592895]
#  [-1.4710043  -0.75592895]
#  [-1.46271695  1.32287566]
#  [-1.4544296   1.32287566]
# ...
